# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a52231-oss/NLP/blob/main/2403A52231_B_09_Deeksha_Ass_1_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk spacy

# %%
# import libraries
import nltk
import spacy

# %%
# smaple text (new-style paragraph)
text = """Artifical Intelligence is transforming the world
It was used in healthcare,education,transportation,etc
NLP helps machines understand human language."""
words = text.split()
word_count = len(words)
print("Number of words: ",word_count)
# Out:
# Number of words:  17

# %%
lowercase_text = text.lower()
print("Lowercase text: ",lowercase_text)
# Out:
# Lowercase text:  artifical intelligence is transforming the world
# it was used in healthcare,education,transportation,etc
# nlp helps machines understand human language.
